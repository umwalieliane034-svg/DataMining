# %%
pip install statsmodels
# Out:
# Collecting statsmodels
#   Using cached statsmodels-0.15.0-cp312-cp312-win_amd64.whl.metadata (9.6 kB)
# Requirement already satisfied: numpy<3,>=1.23.5 in .\anaconda3\envs\ahs2024\Lib\site-packages (from statsmodels) (2.5.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in .\anaconda3\envs\ahs2024\Lib\site-packages (from statsmodels) (1.18.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in .\anaconda3\envs\ahs2024\Lib\site-packages (from statsmodels) (3.0.5)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Using cached patsy-1.0.3-py2.py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: packaging>=21.3 in .\anaconda3\envs\ahs2024\Lib\site-packages (from statsmodels) (26.3)
# Collecting formulaic>=1.1.0 (from statsmodels)
#   Using cached formulaic-1.2.2-py3-none-any.whl.metadata (7.0 kB)
# Collecting interface-meta>=1.2.0 (from formulaic>=1.1.0->statsmodels)
#   Using cached interface_meta-2.0.1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: narwhals>=1.17 in .\anaconda3\envs\ahs2024\Lib\site-packages (from formulaic>=1.1.0->statsmodels) (2.25.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in .\anaconda3\envs\ahs2024\Lib\site-packages (from formulaic>=1.1.0->statsmodels) (4.16.0)
# Requirement already satisfied: wrapt>=1.0 in .\anaconda3\envs\ahs2024\Lib\site-packages (from formulaic>=1.1.0->statsmodels) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\anaconda3\envs\ahs2024\Lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\anaconda3\envs\ahs2024\Lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2026.3)
# Requirement already satisfied: six>=1.5 in .\anaconda3\envs\ahs2024\Lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Using cached statsmodels-0.15.0-cp312-cp312-win_amd64.whl (11.3 MB)
# Using cached formulaic-1.2.2-py3-none-any.whl (118 kB)
# Using cached interface_meta-2.0.1-py3-none-any.whl (15 kB)
# Using cached patsy-1.0.3-py2.py3-none-any.whl (233 kB)
# Installing collected packages: patsy, interface-meta, formulaic, statsmodels
#
#    ---------------------------------------- 0/4 [patsy]
#    ---------------------------------------- 0/4 [patsy]
#    ---------- ----------------------------- 1/4 [interface-meta]
#    -------------------- ------------------- 2/4 [formulaic]
#    -------------------- ------------------- 2/4 [formulaic]
#    -------------------- ------------------- 2/4 [formulaic]
#    -------------------- ------------------- 2/4 [formulaic]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ------------------------------ --------- 3/4 [statsmodels]
#    ---------------------------------------- 4/4 [statsmodels]
#
# Successfully installed formulaic-1.2.2 interface-meta-2.0.1 patsy-1.0.3 statsmodels-0.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ISLP
# Out:
# Collecting ISLP
#   Using cached islp-0.4.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: numpy>=1.7.1 in .\anaconda3\envs\ahs2024\Lib\site-packages (from ISLP) (2.5.2)
# Requirement already satisfied: scipy>=0.9 in .\anaconda3\envs\ahs2024\Lib\site-packages (from ISLP) (1.18.1)
# Requirement already satisfied: pandas>=1.5 in .\anaconda3\envs\ahs2024\Lib\site-packages (from ISLP) (3.0.5)
# Collecting lxml (from ISLP)
#   Using cached lxml-6.1.3-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: scikit-learn>=1.2 in .\anaconda3\envs\ahs2024\Lib\site-packages (from ISLP) (1.9.0)
# Requirement already satisfied: joblib in .\anaconda3\envs\ahs2024\Lib\site-packages (from ISLP) (1.6.0)
# Requirement already satisfied: statsmodels>=0.13 in .\anaconda3\envs\ahs2024\Lib\site-packages (from ISLP) (0.15.0)
# Collecting lifelines (from ISLP)
#   Using cached lifelines-0.30.3-py3-none-any.whl.metadata (3.5 kB)
# Collecting pygam (from ISLP)
#   Using cached pygam-0.12.0-py3-none-any.whl.metadata (9.8 kB)
# Collecting torch (from ISLP)
#   Using cached torch-2.14.0-cp312-cp312-win_amd64.whl.metadata (38 kB)
# Collecting pytorch_lightning (from ISLP)
#   Using cached pytorch_lightning-2.6.5-py3-none-any.whl.metadata (21 kB)
# Collecting torchmetrics (from ISLP)
#   Using cached torchmetrics-1.9.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\anaconda3\envs\ahs2024\Lib\site-packages (from pandas>=1.5->ISLP) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\anaconda3\envs\ahs2024\Lib\site-packages (from pandas>=1.5->ISLP) (2026.3)
# Requirement already satisfied: six>=1.5 in .\anaconda3\envs\ahs2024\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.5->ISLP) (1.17.0)
# Requirement already satisfied: narwhals>=2.0.1 in .\anaconda3\envs\ahs2024\Lib\site-packages (from scikit-learn>=1.2->ISLP) (2.25.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in .\anaconda3\envs\ahs2024\Lib\site-packages (from scikit-learn>=1.2->ISLP) (3.6.0)
# Requirement already satisfied: cloudpickle>=3.0 in .\anaconda3\envs\ahs2024\Lib\site-packages (from joblib->ISLP) (3.1.2)
# Requirement already satisfied: patsy>=0.5.6 in .\anaconda3\envs\ahs2024\Lib\site-packages (from statsmodels>=0.13->ISLP) (1.0.3)
# Requirement already satisfied: packaging>=21.3 in .\anaconda3\envs\ahs2024\Lib\site-packages (from statsmodels>=0.13->ISLP) (26.3)
# Requirement already satisfied: formulaic>=1.1.0 in .\anaconda3\envs\ahs2024\Lib\site-packages (from statsmodels>=0.13->ISLP) (1.2.2)
# Requirement already satisfied: interface-meta>=1.2.0 in .\anaconda3\envs\ahs2024\Lib\site-packages (from formulaic>=1.1.0->statsmodels>=0.13->ISLP) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in .\anaconda3\envs\ahs2024\Lib\site-packages (from formulaic>=1.1.0->statsmodels>=0.13->ISLP) (4.16.0)
# Requirement already satisfied: wrapt>=1.0 in .\anaconda3\envs\ahs2024\Lib\site-packages (from formulaic>=1.1.0->statsmodels>=0.13->ISLP) (2.4.0)
# Collecting pandas>=1.5 (from ISLP)
#   Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib>=3.0 in .\anaconda3\envs\ahs2024\Lib\site-packages (from lifelines->ISLP) (3.11.1)
# Collecting autograd>=1.5 (from lifelines->ISLP)
#   Using cached autograd-1.9.1-py3-none-any.whl.metadata (6.1 kB)
# Collecting autograd-gamma>=0.3 (from lifelines->ISLP)
#   Using cached autograd_gamma-0.5.0-py3-none-any.whl
# Collecting pytz>=2020.1 (from pandas>=1.5->ISLP)
#   Using cached pytz-2026.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: contourpy>=1.0.1 in .\anaconda3\envs\ahs2024\Lib\site-packages (from matplotlib>=3.0->lifelines->ISLP) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\anaconda3\envs\ahs2024\Lib\site-packages (from matplotlib>=3.0->lifelines->ISLP) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in .\anaconda3\envs\ahs2024\Lib\site-packages (from matplotlib>=3.0->lifelines->ISLP) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\anaconda3\envs\ahs2024\Lib\site-packages (from matplotlib>=3.0->lifelines->ISLP) (1.5.1)
# Requirement already satisfied: pillow>=9 in .\anaconda3\envs\ahs2024\Lib\site-packages (from matplotlib>=3.0->lifelines->ISLP) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in .\anaconda3\envs\ahs2024\Lib\site-packages (from matplotlib>=3.0->lifelines->ISLP) (3.3.2)
# Collecting progressbar2<5,>=4.2.0 (from pygam->ISLP)
#   Using cached progressbar2-4.6.0-py3-none-any.whl.metadata (10 kB)
# Collecting scipy>=0.9 (from ISLP)
#   Using cached scipy-1.16.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting python-utils>=3.8.1 (from progressbar2<5,>=4.2.0->pygam->ISLP)
#   Using cached python_utils-4.0.1-py3-none-any.whl.metadata (14 kB)
# Collecting tqdm>=4.57.0 (from pytorch_lightning->ISLP)
#   Using cached tqdm-4.70.0-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: PyYAML>5.4 in .\anaconda3\envs\ahs2024\Lib\site-packages (from pytorch_lightning->ISLP) (6.0.3)
# Collecting fsspec>=2022.5.0 (from fsspec[http]>=2022.5.0->pytorch_lightning->ISLP)
#   Using cached fsspec-2026.7.0-py3-none-any.whl.metadata (10 kB)
# Collecting lightning-utilities>=0.10.0 (from pytorch_lightning->ISLP)
#   Using cached lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>=2022.5.0->pytorch_lightning->ISLP)
#   Using cached aiohttp-3.14.3-cp312-cp312-win_amd64.whl.metadata (8.5 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->ISLP)
#   Using cached aiohappyeyeballs-2.7.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->ISLP)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in .\anaconda3\envs\ahs2024\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->ISLP) (26.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->ISLP)
#   Using cached frozenlist-1.8.0-cp312-cp312-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->ISLP)
#   Using cached multidict-6.7.1-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->ISLP)
#   Using cached propcache-0.5.2-cp312-cp312-win_amd64.whl.metadata (17 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->ISLP)
#   Using cached yarl-1.24.5-cp312-cp312-win_amd64.whl.metadata (107 kB)
# Requirement already satisfied: idna>=2.0 in .\anaconda3\envs\ahs2024\Lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->ISLP) (3.19)
# Collecting filelock (from torch->ISLP)
#   Using cached filelock-3.32.5-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: setuptools>=77.0.3 in .\anaconda3\envs\ahs2024\Lib\site-packages (from torch->ISLP) (83.0.0)
# Collecting sympy>=1.13.3 (from torch->ISLP)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch->ISLP)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in .\anaconda3\envs\ahs2024\Lib\site-packages (from torch->ISLP) (3.1.6)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch->ISLP)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: colorama in .\anaconda3\envs\ahs2024\Lib\site-packages (from tqdm>=4.57.0->pytorch_lightning->ISLP) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in .\anaconda3\envs\ahs2024\Lib\site-packages (from jinja2->torch->ISLP) (3.0.3)
# Using cached islp-0.4.1-py3-none-any.whl (16.6 MB)
# Using cached lifelines-0.30.3-py3-none-any.whl (409 kB)
# Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl (11.0 MB)
# Using cached autograd-1.9.1-py3-none-any.whl (54 kB)
# Using cached pytz-2026.3.post1-py2.py3-none-any.whl (508 kB)
# Using cached lxml-6.1.3-cp312-cp312-win_amd64.whl (4.0 MB)
# Using cached pygam-0.12.0-py3-none-any.whl (84 kB)
# Using cached progressbar2-4.6.0-py3-none-any.whl (104 kB)
# Using cached scipy-1.16.3-cp312-cp312-win_amd64.whl (38.6 MB)
# Using cached python_utils-4.0.1-py3-none-any.whl (39 kB)
# Using cached pytorch_lightning-2.6.5-py3-none-any.whl (852 kB)
# Using cached fsspec-2026.7.0-py3-none-any.whl (206 kB)
# Using cached aiohttp-3.14.3-cp312-cp312-win_amd64.whl (476 kB)
# Using cached multidict-6.7.1-cp312-cp312-win_amd64.whl (46 kB)
# Using cached yarl-1.24.5-cp312-cp312-win_amd64.whl (97 kB)
# Using cached aiohappyeyeballs-2.7.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached frozenlist-1.8.0-cp312-cp312-win_amd64.whl (44 kB)
# Using cached lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Using cached propcache-0.5.2-cp312-cp312-win_amd64.whl (42 kB)
# Downloading torch-2.14.0-cp312-cp312-win_amd64.whl (124.1 MB)
#    ---------------------------------------- 0.0/124.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/124.1 MB ? eta -:--:--
#    ---------------------------------------- 0.5/124.1 MB 1.7 MB/s eta 0:01:14
#    ---------------------------------------- 1.3/124.1 MB 2.7 MB/s eta 0:00:46
#     --------------------------------------- 2.1/124.1 MB 3.0 MB/s eta 0:00:41
#     --------------------------------------- 2.6/124.1 MB 2.8 MB/s eta 0:00:43
#    - -------------------------------------- 3.1/124.1 MB 2.6 MB/s eta 0:00:46
#    - -------------------------------------- 3.7/124.1 MB 2.8 MB/s eta 0:00:44
#    - -------------------------------------- 4.2/124.1 MB 2.7 MB/s eta 0:00:45
#    - -------------------------------------- 5.0/124.1 MB 2.7 MB/s eta 0:00:45
#    - -------------------------------------- 5.5/124.1 MB 2.7 MB/s eta 0:00:44
#    -- ------------------------------------- 6.3/124.1 MB 2.8 MB/s eta 0:00:43
#    -- ------------------------------------- 7.1/124.1 MB 2.9 MB/s eta 0:00:41
#    -- ------------------------------------- 7.9/124.1 MB 2.9 MB/s eta 0:00:40
#    -- ------------------------------------- 8.7/124.1 MB 3.0 MB/s eta 0:00:39
#    -- ------------------------------------- 9.2/124.1 MB 2.9 MB/s eta 0:00:40
#    --- ------------------------------------ 9.7/124.1 MB 2.9 MB/s eta 0:00:39
#    --- ------------------------------------ 10.5/124.1 MB 3.0 MB/s eta 0:00:39
#    --- ------------------------------------ 11.5/124.1 MB 3.1 MB/s eta 0:00:37
#    ---- ----------------------------------- 12.6/124.1 MB 3.1 MB/s eta 0:00:36
#    ---- ----------------------------------- 13.6/124.1 MB 3.2 MB/s eta 0:00:35
#    ---- ----------------------------------- 14.4/124.1 MB 3.3 MB/s eta 0:00:34
#    ---- ----------------------------------- 14.9/124.1 MB 3.2 MB/s eta 0:00:34
#    ----- ---------------------------------- 16.0/124.1 MB 3.3 MB/s eta 0:00:33
#    ----- ---------------------------------- 17.0/124.1 MB 3.3 MB/s eta 0:00:33
#    ----- ---------------------------------- 17.8/124.1 MB 3.4 MB/s eta 0:00:32
#    ----- ---------------------------------- 18.6/124.1 MB 3.4 MB/s eta 0:00:32
#    ------ --------------------------------- 19.7/124.1 MB 3.4 MB/s eta 0:00:31
#    ------ --------------------------------- 21.0/124.1 MB 3.5 MB/s eta 0:00:30
#    ------- -------------------------------- 22.0/124.1 MB 3.6 MB/s eta 0:00:29
#    ------- -------------------------------- 23.3/124.1 MB 3.6 MB/s eta 0:00:28
#    ------- -------------------------------- 24.4/124.1 MB 3.7 MB/s eta 0:00:27
#    -------- ------------------------------- 26.0/124.1 MB 3.8 MB/s eta 0:00:26
#    -------- ------------------------------- 26.7/124.1 MB 3.8 MB/s eta 0:00:26
#    --------- ------------------------------ 28.0/124.1 MB 3.9 MB/s eta 0:00:25
#    --------- ------------------------------ 28.8/124.1 MB 3.8 MB/s eta 0:00:25
#    --------- ------------------------------ 29.9/124.1 MB 3.9 MB/s eta 0:00:25
#    --------- ------------------------------ 30.7/124.1 MB 3.9 MB/s eta 0:00:25
#    ---------- ----------------------------- 31.5/124.1 MB 3.9 MB/s eta 0:00:24
#    ---------- ----------------------------- 32.8/124.1 MB 3.9 MB/s eta 0:00:24
#    ---------- ----------------------------- 34.1/124.1 MB 4.0 MB/s eta 0:00:23
#    ----------- ---------------------------- 35.4/124.1 MB 4.0 MB/s eta 0:00:23
#    ----------- ---------------------------- 36.4/124.1 MB 4.0 MB/s eta 0:00:22
#    ------------ --------------------------- 37.5/124.1 MB 4.1 MB/s eta 0:00:22
#    ------------ --------------------------- 38.5/124.1 MB 4.1 MB/s eta 0:00:22
#    ------------ --------------------------- 39.3/124.1 MB 4.1 MB/s eta 0:00:21
#    ------------ --------------------------- 40.1/124.1 MB 4.0 MB/s eta 0:00:21
#    ------------- -------------------------- 40.9/124.1 MB 4.0 MB/s eta 0:00:21
#    ------------- -------------------------- 41.7/124.1 MB 4.0 MB/s eta 0:00:21
#    ------------- -------------------------- 42.5/124.1 MB 4.0 MB/s eta 0:00:21
#    ------------- -------------------------- 43.3/124.1 MB 4.0 MB/s eta 0:00:21
#    -------------- ------------------------- 44.0/124.1 MB 4.0 MB/s eta 0:00:20
#    -------------- ------------------------- 45.1/124.1 MB 4.0 MB/s eta 0:00:20
#    -------------- ------------------------- 45.9/124.1 MB 4.0 MB/s eta 0:00:20
#    --------------- ------------------------ 46.9/124.1 MB 4.0 MB/s eta 0:00:20
#    --------------- ------------------------ 47.4/124.1 MB 4.0 MB/s eta 0:00:20
#    --------------- ------------------------ 48.8/124.1 MB 4.0 MB/s eta 0:00:19
#    ---------------- ----------------------- 50.1/124.1 MB 4.1 MB/s eta 0:00:19
#    ---------------- ----------------------- 50.9/124.1 MB 4.1 MB/s eta 0:00:18
#    ---------------- ----------------------- 52.2/124.1 MB 4.1 MB/s eta 0:00:18
#    ----------------- ---------------------- 53.2/124.1 MB 4.1 MB/s eta 0:00:18
#    ----------------- ---------------------- 53.7/124.1 MB 4.1 MB/s eta 0:00:18
#    ----------------- ---------------------- 55.1/124.1 MB 4.1 MB/s eta 0:00:17
#    ------------------ --------------------- 56.1/124.1 MB 4.1 MB/s eta 0:00:17
#    ------------------ --------------------- 57.1/124.1 MB 4.1 MB/s eta 0:00:17
#    ------------------ --------------------- 58.2/124.1 MB 4.1 MB/s eta 0:00:16
#    ------------------- -------------------- 59.5/124.1 MB 4.2 MB/s eta 0:00:16
#    ------------------- -------------------- 61.1/124.1 MB 4.2 MB/s eta 0:00:16
#    -------------------- ------------------- 62.1/124.1 MB 4.2 MB/s eta 0:00:15
#    -------------------- ------------------- 63.4/124.1 MB 4.2 MB/s eta 0:00:15
#    -------------------- ------------------- 64.5/124.1 MB 4.2 MB/s eta 0:00:15
#    --------------------- ------------------ 65.5/124.1 MB 4.3 MB/s eta 0:00:14
#    --------------------- ------------------ 66.8/124.1 MB 4.3 MB/s eta 0:00:14
#    ---------------------- ----------------- 68.4/124.1 MB 4.3 MB/s eta 0:00:13
#    ---------------------- ----------------- 70.0/124.1 MB 4.3 MB/s eta 0:00:13
#    ---------------------- ----------------- 71.3/124.1 MB 4.4 MB/s eta 0:00:13
#    ----------------------- ---------------- 72.4/124.1 MB 4.4 MB/s eta 0:00:12
#    ----------------------- ---------------- 73.1/124.1 MB 4.4 MB/s eta 0:00:12
#    ----------------------- ---------------- 74.2/124.1 MB 4.4 MB/s eta 0:00:12
#    ------------------------ --------------- 75.0/124.1 MB 4.4 MB/s eta 0:00:12
#    ------------------------ --------------- 76.0/124.1 MB 4.4 MB/s eta 0:00:11
#    ------------------------ --------------- 77.3/124.1 MB 4.4 MB/s eta 0:00:11
#    ------------------------- -------------- 78.6/124.1 MB 4.4 MB/s eta 0:00:11
#    ------------------------- -------------- 80.2/124.1 MB 4.4 MB/s eta 0:00:10
#    -------------------------- ------------- 81.5/124.1 MB 4.5 MB/s eta 0:00:10
#    -------------------------- ------------- 82.8/124.1 MB 4.5 MB/s eta 0:00:10
#    --------------------------- ------------ 84.1/124.1 MB 4.5 MB/s eta 0:00:09
#    --------------------------- ------------ 85.5/124.1 MB 4.5 MB/s eta 0:00:09
#    --------------------------- ------------ 86.8/124.1 MB 4.5 MB/s eta 0:00:09
#    ---------------------------- ----------- 88.3/124.1 MB 4.6 MB/s eta 0:00:08
#    ---------------------------- ----------- 89.7/124.1 MB 4.6 MB/s eta 0:00:08
#    ----------------------------- ---------- 91.0/124.1 MB 4.6 MB/s eta 0:00:08
#    ----------------------------- ---------- 92.3/124.1 MB 4.6 MB/s eta 0:00:07
#    ------------------------------ --------- 93.6/124.1 MB 4.6 MB/s eta 0:00:07
#    ------------------------------ --------- 95.2/124.1 MB 4.7 MB/s eta 0:00:07
#    ------------------------------- -------- 96.5/124.1 MB 4.7 MB/s eta 0:00:06
#    ------------------------------- -------- 97.8/124.1 MB 4.7 MB/s eta 0:00:06
#    ------------------------------- -------- 99.1/124.1 MB 4.7 MB/s eta 0:00:06
#    -------------------------------- ------- 100.4/124.1 MB 4.7 MB/s eta 0:00:06
#    -------------------------------- ------- 101.7/124.1 MB 4.7 MB/s eta 0:00:05
#    --------------------------------- ------ 103.3/124.1 MB 4.7 MB/s eta 0:00:05
#    --------------------------------- ------ 104.6/124.1 MB 4.8 MB/s eta 0:00:05
#    ---------------------------------- ----- 105.9/124.1 MB 4.8 MB/s eta 0:00:04
#    ---------------------------------- ----- 107.5/124.1 MB 4.8 MB/s eta 0:00:04
#    ----------------------------------- ---- 108.8/124.1 MB 4.8 MB/s eta 0:00:04
#    ----------------------------------- ---- 110.1/124.1 MB 4.8 MB/s eta 0:00:03
#    ----------------------------------- ---- 111.4/124.1 MB 4.8 MB/s eta 0:00:03
#    ------------------------------------ --- 112.7/124.1 MB 4.8 MB/s eta 0:00:03
#    ------------------------------------ --- 114.3/124.1 MB 4.9 MB/s eta 0:00:03
#    ------------------------------------- -- 115.6/124.1 MB 4.9 MB/s eta 0:00:02
#    ------------------------------------- -- 116.9/124.1 MB 4.9 MB/s eta 0:00:02
#    -------------------------------------- - 118.5/124.1 MB 4.9 MB/s eta 0:00:02
#    -------------------------------------- - 119.8/124.1 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  121.1/124.1 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  122.4/124.1 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  123.7/124.1 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.1 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.1 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.1 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 124.1/124.1 MB 4.8 MB/s  0:00:26
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----------------------------------- ---- 1.8/2.1 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 1.9 MB/s  0:00:01
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 3.5 MB/s  0:00:00
# Using cached torchmetrics-1.9.0-py3-none-any.whl (983 kB)
# Downloading tqdm-4.70.0-py3-none-any.whl (80 kB)
# Downloading filelock-3.32.5-py3-none-any.whl (100 kB)
# Installing collected packages: pytz, mpmath, tqdm, sympy, scipy, python-utils, propcache, networkx, multidict, lxml, lightning-utilities, fsspec, frozenlist, filelock, autograd, aiohappyeyeballs, yarl, torch, progressbar2, pandas, autograd-gamma, aiosignal, torchmetrics, pygam, aiohttp, lifelines, pytorch_lightning, ISLP
#
#    ----------------------------------------  0/28 [pytz]
#    ----------------------------------------  0/28 [pytz]
#    ----------------------------------------  0/28 [pytz]
#    ----------------------------------------  0/28 [pytz]
#    ----------------------------------------  0/28 [pytz]
#    ----------------------------------------  0/28 [pytz]
#    ----------------------------------------  0/28 [pytz]
#    ----------------------------------------  0/28 [pytz]
#    - --------------------------------------  1/28 [mpmath]
#    - --------------------------------------  1/28 [mpmath]
#    - --------------------------------------  1/28 [mpmath]
#    - --------------------------------------  1/28 [mpmath]
#    - --------------------------------------  1/28 [mpmath]
#    - --------------------------------------  1/28 [mpmath]
#    - --------------------------------------  1/28 [mpmath]
#    - --------------------------------------  1/28 [mpmath]
#    - --------------------------------------  1/28 [mpmath]
#    - --------------------------------------  1/28 [mpmath]
#    - --------------------------------------  1/28 [mpmath]
#    - --------------------------------------  1/28 [mpmath]
#    -- -------------------------------------  2/28 [tqdm]
#    -- -------------------------------------  2/28 [tqdm]
#    -- -------------------------------------  2/28 [tqdm]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#    ---- -----------------------------------  3/28 [sympy]
#   Attempting uninstall: scipy
#    ---- -----------------------------------  3/28 [sympy]
#     Found existing installation: scipy 1.18.1
#    ---- -----------------------------------  3/28 [sympy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#     Uninstalling scipy-1.18.1:
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#       Successfully uninstalled scipy-1.18.1
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ----- ----------------------------------  4/28 [scipy]
#    ------- --------------------------------  5/28 [python-utils]
#    -------- -------------------------------  6/28 [propcache]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
#    ---------- -----------------------------  7/28 [networkx]
# ...
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    --------------------------- ------------ 19/28 [pandas]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    ------------------------------- -------- 22/28 [torchmetrics]
#    -------------------------------- ------- 23/28 [pygam]
#    -------------------------------- ------- 23/28 [pygam]
#    -------------------------------- ------- 23/28 [pygam]
#    ---------------------------------- ----- 24/28 [aiohttp]
#    ---------------------------------- ----- 24/28 [aiohttp]
#    ---------------------------------- ----- 24/28 [aiohttp]
#    ---------------------------------- ----- 24/28 [aiohttp]
#    ---------------------------------- ----- 24/28 [aiohttp]
#    ---------------------------------- ----- 24/28 [aiohttp]
#    ---------------------------------- ----- 24/28 [aiohttp]
#    ----------------------------------- ---- 25/28 [lifelines]
#    ----------------------------------- ---- 25/28 [lifelines]
#    ----------------------------------- ---- 25/28 [lifelines]
#    ----------------------------------- ---- 25/28 [lifelines]
#    ----------------------------------- ---- 25/28 [lifelines]
#    ------------------------------------- -- 26/28 [pytorch_lightning]
#    ------------------------------------- -- 26/28 [pytorch_lightning]
#    ------------------------------------- -- 26/28 [pytorch_lightning]
#    ------------------------------------- -- 26/28 [pytorch_lightning]
#    ------------------------------------- -- 26/28 [pytorch_lightning]
#    ------------------------------------- -- 26/28 [pytorch_lightning]
#    ------------------------------------- -- 26/28 [pytorch_lightning]
#    ------------------------------------- -- 26/28 [pytorch_lightning]
#    ------------------------------------- -- 26/28 [pytorch_lightning]
#    ------------------------------------- -- 26/28 [pytorch_lightning]
#    ------------------------------------- -- 26/28 [pytorch_lightning]
#    ------------------------------------- -- 26/28 [pytorch_lightning]
#    ------------------------------------- -- 26/28 [pytorch_lightning]
#    ------------------------------------- -- 26/28 [pytorch_lightning]
#    ------------------------------------- -- 26/28 [pytorch_lightning]
#    ------------------------------------- -- 26/28 [pytorch_lightning]
#    ------------------------------------- -- 26/28 [pytorch_lightning]
#    ------------------------------------- -- 26/28 [pytorch_lightning]
#    ------------------------------------- -- 26/28 [pytorch_lightning]
#    ------------------------------------- -- 26/28 [pytorch_lightning]
#    ------------------------------------- -- 26/28 [pytorch_lightning]
#    -------------------------------------- - 27/28 [ISLP]
#    -------------------------------------- - 27/28 [ISLP]
#    -------------------------------------- - 27/28 [ISLP]
#    ---------------------------------------- 28/28 [ISLP]
#
# Successfully installed ISLP-0.4.1 aiohappyeyeballs-2.7.1 aiohttp-3.14.3 aiosignal-1.4.0 autograd-1.9.1 autograd-gamma-0.5.0 filelock-3.32.5 frozenlist-1.8.0 fsspec-2026.7.0 lifelines-0.30.3 lightning-utilities-0.15.3 lxml-6.1.3 mpmath-1.3.0 multidict-6.7.1 networkx-3.6.1 pandas-2.3.3 progressbar2-4.6.0 propcache-0.5.2 pygam-0.12.0 python-utils-4.0.1 pytorch_lightning-2.6.5 pytz-2026.3.post1 scipy-1.16.3 sympy-1.14.0 torch-2.14.0 torchmetrics-1.9.0 tqdm-4.70.0 yarl-1.24.5
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'C:\Users\user\anaconda3\envs\ahs2024\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script isympy.exe is installed in 'C:\Users\user\anaconda3\envs\ahs2024\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts torchfrtrace.exe and torchrun.exe are installed in 'C:\Users\user\anaconda3\envs\ahs2024\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script progressbar.exe is installed in 'C:\Users\user\anaconda3\envs\ahs2024\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\user\anaconda3\envs\ahs2024\Lib\site-packages\~andas'.
#   You can safely remove it manually.

# %%
import numpy as np
import pandas as pd
from matplotlib.pyplot import subplots
from statsmodels.datasets import get_rdataset
import sklearn.model_selection as skm
from ISLP import load_data, confusion_table
from ISLP.models import ModelSpec as MS

# %%
from sklearn.tree import (DecisionTreeClassifier as DTC,DecisionTreeRegressor as DTR,
plot_tree,export_text)
from sklearn.metrics import (accuracy_score,
log_loss)
from sklearn.ensemble import \
(RandomForestRegressor as RF,
GradientBoostingRegressor as GBR)
from ISLP.bart import BART

# %%
Carseats = load_data('Carseats')
High = np.where(Carseats.Sales > 8,
"Yes",
"No")

# %%
model = MS(Carseats.columns.drop('Sales'), intercept=False)
D = model.fit_transform(Carseats)
feature_names = list(D.columns)
X = np.asarray(D)

# %%
clf = DTC(criterion='entropy',max_depth=3,random_state=0)
clf.fit(X, High)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)

# %%
accuracy_score(High, clf.predict(X))
# Out:
# 0.79

# %%
resid_dev = np.sum(log_loss(High, clf.predict_proba(X)))
resid_dev
# Out:
# np.float64(0.4710647062649358)

# %%
ax = subplots(figsize=(12,12))[1]
plot_tree(clf,
feature_names=feature_names,
ax=ax);

# %%
print(export_text(clf,
feature_names=feature_names,
show_weights=True))
# Out:
# |--- ShelveLoc[Good] <= 0.50
# |   |--- Price <= 92.50
# |   |   |--- Income <= 57.00
# |   |   |   |--- weights: [7.00, 3.00] class: No
# |   |   |--- Income >  57.00
# |   |   |   |--- weights: [7.00, 29.00] class: Yes
# |   |--- Price >  92.50
# |   |   |--- Advertising <= 13.50
# |   |   |   |--- weights: [183.00, 41.00] class: No
# |   |   |--- Advertising >  13.50
# |   |   |   |--- weights: [20.00, 25.00] class: Yes
# |--- ShelveLoc[Good] >  0.50
# |   |--- Price <= 135.00
# |   |   |--- US[Yes] <= 0.50
# |   |   |   |--- weights: [6.00, 11.00] class: Yes
# |   |   |--- US[Yes] >  0.50
# |   |   |   |--- weights: [2.00, 49.00] class: Yes
# |   |--- Price >  135.00
# |   |   |--- Income <= 46.00
# |   |   |   |--- weights: [6.00, 0.00] class: No
# |   |   |--- Income >  46.00
# |   |   |   |--- weights: [5.00, 6.00] class: Yes

# %%
validation = skm.ShuffleSplit(n_splits=1,test_size=200,random_state=0)
results = skm.cross_validate(clf,D,High,cv=validation)
results['test_score']
# Out:
# array([0.685])

# %%
(X_train,X_test,High_train,
High_test) = skm.train_test_split(X,High,
test_size=0.5,
random_state=0)

# %%
clf = DTC(criterion='entropy', random_state=0)
clf.fit(X_train, High_train)
accuracy_score(High_test, clf.predict(X_test))
# Out:
# 0.735

# %%
ccp_path = clf.cost_complexity_pruning_path(X_train, High_train)
kfold = skm.KFold(10,random_state=1,shuffle=True)

# %%
grid = skm.GridSearchCV(clf,
{'ccp_alpha': ccp_path.ccp_alphas},
refit=True,
cv=kfold,scoring='accuracy')
grid.fit(X_train, High_train)
grid.best_score_
# Out:
# np.float64(0.685)

# %%
ax = subplots(figsize=(12, 12))[1]
best_ = grid.best_estimator_
plot_tree(best_,
feature_names=feature_names,
ax=ax);

# %%
best_.tree_.n_leaves
# Out:
# np.int64(30)

# %%
print(accuracy_score(High_test,best_.predict(X_test)))
confusion = confusion_table(best_.predict(X_test),High_test)
confusion
# Out:
# 0.72
# Truth      No  Yes
# Predicted
# No         94   32
# Yes        24   50

# %%
Boston = load_data("Boston")
model = MS(Boston.columns.drop('medv'), intercept=False)
D = model.fit_transform(Boston)
feature_names = list(D.columns)
X = np.asarray(D)

# %%
(X_train,X_test,y_train,
y_test) = skm.train_test_split(X,
Boston['medv'],
test_size=0.3,
random_state=0)

# %%
reg = DTR(max_depth=3)
reg.fit(X_train, y_train)
ax = subplots(figsize=(12,12))[1]
plot_tree(reg,
feature_names=feature_names,
ax=ax);

# %%
ccp_path = reg.cost_complexity_pruning_path(X_train, y_train)
kfold = skm.KFold(5,
shuffle=True,
random_state=10)
grid = skm.GridSearchCV(reg,
{'ccp_alpha': ccp_path.ccp_alphas},
refit=True,
cv=kfold,
scoring='neg_mean_squared_error')
G = grid.fit(X_train, y_train)

# %%
best_ = grid.best_estimator_
np.mean((y_test- best_.predict(X_test))**2)
# Out:
# np.float64(28.06985754975404)

# %%
ax = subplots(figsize=(12,12))[1]
plot_tree(G.best_estimator_,
feature_names=feature_names,
ax=ax);

# %%
bag_boston = RF(max_features=X_train.shape[1], random_state=0)
bag_boston.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_features=12, random_state=0)

# %%
ax = subplots(figsize=(8,8))[1]
y_hat_bag = bag_boston.predict(X_test)
ax.scatter(y_hat_bag, y_test)
np.mean((y_test- y_hat_bag)**2)
# Out:
# np.float64(14.612930407894737)

# %%
bag_boston = RF(max_features=X_train.shape[1],
n_estimators=500,
random_state=0).fit(X_train, y_train)
y_hat_bag = bag_boston.predict(X_test)
np.mean((y_test- y_hat_bag)**2)
# Out:
# np.float64(14.610410025789477)

# %%
RF_boston = RF(max_features=6,
random_state=0).fit(X_train, y_train)
y_hat_RF = RF_boston.predict(X_test)
np.mean((y_test- y_hat_RF)**2)
# Out:
# np.float64(20.261844203947373)

# %%
feature_imp = pd.DataFrame(
{'importance':RF_boston.feature_importances_},
index=feature_names)
feature_imp.sort_values(by='importance', ascending=False)
# Out:
#          importance
# lstat      0.357250
# rm         0.332050
# ptratio    0.068107
# crim       0.058243
# indus      0.052632
# dis        0.042471
# nox        0.032385
# tax        0.025497
# age        0.020530
# rad        0.005148
# chas       0.003381
# zn         0.002305

# %%
boost_boston = GBR(n_estimators=5000,
learning_rate=0.001,
max_depth=3,
random_state=0)
boost_boston.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.001, n_estimators=5000,
#                           random_state=0)

# %%
test_error = np.zeros_like(boost_boston.train_score_)
for idx, y_ in enumerate(boost_boston.staged_predict(X_test)):
    test_error[idx] = np.mean((y_test- y_)**2)
plot_idx = np.arange(boost_boston.train_score_.shape[0])
ax = subplots(figsize=(8,8))[1]
ax.plot(plot_idx,
boost_boston.train_score_,
'b',
label='Training')
ax.plot(plot_idx,
test_error,
'r',
label='Test')
ax.legend();

# %%
y_hat_boost = boost_boston.predict(X_test);
np.mean((y_test- y_hat_boost)**2)
# Out:
# np.float64(14.484189040407578)

# %%
boost_boston = GBR(n_estimators=5000,
learning_rate=0.2,
max_depth=3,
random_state=0)
boost_boston.fit(X_train,
y_train)
y_hat_boost = boost_boston.predict(X_test);
np.mean((y_test- y_hat_boost)**2)
# Out:
# np.float64(14.501514553719547)

# %%
bart_boston = BART(random_state=0, burnin=5, ndraw=15)
bart_boston.fit(X_train, y_train)
# Out:
# BART(burnin=5, ndraw=15, random_state=0)

# %%
yhat_test = bart_boston.predict(X_test.astype(np.float32))
np.mean((y_test- yhat_test)**2)
# Out:
# np.float64(22.145009458109232)

# %%
var_inclusion = pd.Series(bart_boston.variable_inclusion_.mean(0),
index=D.columns)
var_inclusion
# Out:
# crim       26.933333
# zn         27.866667
# indus      26.466667
# chas       22.466667
# nox        26.600000
# rm         29.800000
# age        22.733333
# dis        26.466667
# rad        23.666667
# tax        24.133333
# ptratio    24.266667
# lstat      31.000000
# dtype: float64
