# %% [markdown]
# Question 9 — Boston Housing Data

# %%
from ISLP import load_data

Boston = load_data("Boston")
Boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
Boston['medv']
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %% [markdown]
# (a) Estimate the population mean

# %%
mu_hat = Boston['medv'].mean()

print(mu_hat)
# Out:
# 22.532806324110677

# %% [markdown]
# (b) Estimate the standard error

# %%
import numpy as np

# %%
se_mu = Boston['medv'].std() / np.sqrt(Boston.shape[0])

print(se_mu)
# Out:
# 0.40886114749753505

# %% [markdown]
# (c) Bootstrap estimate of the standard error

# %%
import numpy as np

rng = np.random.default_rng(1)

bootstrap_means = []

for i in range(10000):
    sample = rng.choice(
        Boston['medv'],
        size=len(Boston),
        replace=True
    )
    
    bootstrap_means.append(sample.mean())

bootstrap_se = np.std(bootstrap_means, ddof=1)

print(bootstrap_se)
# Out:
# 0.4097870815137789

# %% [markdown]
# (d) 95% Confidence Interval

# %%
lower = mu_hat - 2 * bootstrap_se
upper = mu_hat + 2 * bootstrap_se

print(lower, upper)
# Out:
# 21.71323216108312 23.352380487138234

# %% [markdown]
# (e) Estimate the population median

# %%
mu_med = Boston['medv'].median()

print(mu_med)
# Out:
# 21.2

# %% [markdown]
# (f) Bootstrap standard error of the median

# %%
bootstrap_medians = []

for i in range(10000):
    sample = rng.choice(
        Boston['medv'],
        size=len(Boston),
        replace=True
    )
    
    bootstrap_medians.append(np.median(sample))

bootstrap_median_se = np.std(
    bootstrap_medians,
    ddof=1
)

print(bootstrap_median_se)
# Out:
# 0.38130214647663674

# %% [markdown]
# (g) Estimate the tenth percentile

# %%
np.percentile(Boston['medv'], 10)
# Out:
# np.float64(12.75)

# %% [markdown]
# (h) Bootstrap standard error of the tenth percentile

# %%
bootstrap_percentiles = []

for i in range(10000):
    sample = rng.choice(
        Boston['medv'],
        size=len(Boston),
        replace=True
    )
    
    bootstrap_percentiles.append(
        np.percentile(sample, 10)
    )

bootstrap_percentile_se = np.std(
    bootstrap_percentiles,
    ddof=1
)

print(bootstrap_percentile_se)
# Out:
# 0.4999335177073174
